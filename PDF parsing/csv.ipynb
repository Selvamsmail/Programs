# %%
import pandas as pd

# %%
df = pd.read_excel('GMAT_Al_Qs.xlsx')
df
# Out:
#      question_id                                 main_question_stem  \
# 0              1  In a locality, there are thrice as many buses ...
# 1              2  In a school, 20% of the boys learn French whil...
# 2              1  A and B need to do the laundry since their was...
# 3              2  A can write 10 programming codes in 15 hours, ...
# 4              3  A and B can paint 3 walls in 2 hours. Along wi...
# ..           ...                                                ...
# 531           37  A new kind of primate, the fat-tailed lemur, h...
# 532           38  When we think about peoples of the past, we in...
# 533           39  Motorcyclists are told to always wear helmets ...
# 534           40  Even though Carter had fewer quarters in his p...
# 535           41  Rugby is somewhat like American football in th...
#
#     subquestion1 subquestion2 subquestion3  \
# 0            NaN          NaN          NaN
# 1            NaN          NaN          NaN
# ...

# %%
df.index = range(1, len(df) + 1)
df
# Out:
#      question_id                                 main_question_stem  \
# 1              1  In a locality, there are thrice as many buses ...
# 2              2  In a school, 20% of the boys learn French whil...
# 3              1  A and B need to do the laundry since their was...
# 4              2  A can write 10 programming codes in 15 hours, ...
# 5              3  A and B can paint 3 walls in 2 hours. Along wi...
# ..           ...                                                ...
# 532           37  A new kind of primate, the fat-tailed lemur, h...
# 533           38  When we think about peoples of the past, we in...
# 534           39  Motorcyclists are told to always wear helmets ...
# 535           40  Even though Carter had fewer quarters in his p...
# 536           41  Rugby is somewhat like American football in th...
#
#     subquestion1 subquestion2 subquestion3  \
# 1            NaN          NaN          NaN
# 2            NaN          NaN          NaN
# ...

# %%
df.to_excel('gmat_all_qs.xlsx')

# %%
df.to_csv('gmat_all_qs.csv',index = False)
