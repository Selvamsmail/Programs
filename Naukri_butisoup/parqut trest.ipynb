# %%
import pandas as pd

# %%
pd.read_parquet('Naukri_raw3.parquetbak.parquet')
# Out:
#                                                job_title  \
# 0                                        React Developer
# 1      S&C Global Network - AI - Data Architect - Con...
# 2      S&C Global Network - AI - Software & Platform ...
# 3      S&C Global Network - AI - Software & Platform ...
# 4      S&C Global Network - AI - Data Architect - Con...
# ...                                                  ...
# 19218                    Deck Cadet & OS-Container cargo
# 19219            Ordinary Seaman,Wiper & General Steward
# 19220            Deck Cadet & Ordinary Seaman-Panama CDC
# 19221          Deck Cadet,Engine Cadet & General Steward
# 19222          Deck Cadet,Engine Cadet & General Steward
#
#                         company_name     experience           salary  \
# 0      Leading Software Technologies    4 - 8 years  15-25 Lacs P.A.
# 1                          Accenture   5 - 10 years    Not Disclosed
# 2                          Accenture  10 - 12 years    Not Disclosed
# ...
